# %%
import glob
from astropy.io import fits

# 获取所有FITS文件
fits_files = glob.glob('./South/*.fits') + glob.glob('./North/*.fits')

fits_files
# Out:
# ['./South/00_DEC_-13.0_-3.0__06_RA_60.0_70.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__07_RA_70.0_80.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__08_RA_80.0_90.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__09_RA_90.0_100.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__10_RA_100.0_110.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__11_RA_110.0_120.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__12_RA_120.0_130.0__-600kms_600kms.I.fits',
#  './South/00_DEC_-13.0_-3.0__13_RA_130.0_140.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__06_RA_60.0_70.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__07_RA_70.0_80.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__08_RA_80.0_90.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__09_RA_90.0_100.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__10_RA_100.0_110.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__11_RA_110.0_120.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__12_RA_120.0_130.0__-600kms_600kms.I.fits',
#  './South/01_DEC_-3.0_7.0__13_RA_130.0_140.0__-600kms_600kms.I.fits']

# %%
# 定义要修改的header内容
updates = {
    'CTYPE3': ('VRAD', 'Radio velocity (linear)'),
    'SPECSYS': ('LSRK', 'Reference frame of spectral coordinates'),
    'VELOSYS': (0.0, '[m/s] Velocity towards source'),
    'RESTFRQ': (1420405751.77, '[Hz] Line rest frequency')
}

# 批量修改
for filename in fits_files:
    try:
        with fits.open(filename, mode='update') as hdul:
            header = hdul[0].header

            # 更新header
            for key, (value, comment) in updates.items():
                header[key] = (value, comment)

            hdul.flush()
            print(f"已更新: {filename}")

    except Exception as e:
        print(f"错误: {filename} - {e}")

print("处理完成!")
# Out:
# 已更新: ./South/00_DEC_-13.0_-3.0__06_RA_60.0_70.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__07_RA_70.0_80.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__08_RA_80.0_90.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__09_RA_90.0_100.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__10_RA_100.0_110.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__11_RA_110.0_120.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__12_RA_120.0_130.0__-600kms_600kms.I.fits
# 已更新: ./South/00_DEC_-13.0_-3.0__13_RA_130.0_140.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__06_RA_60.0_70.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__07_RA_70.0_80.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__08_RA_80.0_90.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__09_RA_90.0_100.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__10_RA_100.0_110.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__11_RA_110.0_120.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__12_RA_120.0_130.0__-600kms_600kms.I.fits
# 已更新: ./South/01_DEC_-3.0_7.0__13_RA_130.0_140.0__-600kms_600kms.I.fits
# 处理完成!
